# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
import json


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# !pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config info
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL and request your results in Celsius
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Get weather data
weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=3))
# Out:
# {
#    "coord": {
#       "lon": -90.35,
#       "lat": -0.74
#    },
#    "weather": [
#       {
#          "id": 803,
#          "main": "Clouds",
#          "description": "broken clouds",
#          "icon": "04n"
#       }
#    ],
#    "base": "stations",
#    "main": {
#       "temp": 70,
#       "feels_like": 75.18,
#       "temp_min": 70,
#       "temp_max": 70,
#       "pressure": 1011,
#       "humidity": 91
#    },
#    "visibility": 10000,
#    "wind": {
#       "speed": 1.99,
#       "deg": 213,
#       "gust": 5.99
#    },
#    "clouds": {
#       "all": 59
#    },
#    "dt": 1595206521,
#    "sys": {
#       "type": 3,
#       "id": 2005652,
#       "country": "EC",
#       "sunrise": 1595160306,
#       "sunset": 1595203798
#    },
#    "timezone": -21600,
#    "id": 3652764,
#    "name": "Puerto Ayora",
#    "cod": 200
# }

# %%
# Get weather data
names = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []

count = 1
next_record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
    
        # append data into empty sets
        names.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
    
        # conditional for records and sets
        if count <= 50:
            print(f"Processing Record {count} of Set {next_record} | {city_record}")
            count += 1 
        
        else: 
            count = 0
            next_record += 1
            print(f"Processing Record {count} of Set {next_record} | {city_record}")
            count += 1
    except: 
        print("City not found. Skipping...")
        pass
        

print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | Chokurdakh
# Processing Record 2 of Set 1 | Ishimbay
# Processing Record 3 of Set 1 | Port Keats
# Processing Record 4 of Set 1 | Pevek
# Processing Record 5 of Set 1 | George Town
# Processing Record 6 of Set 1 | Ushuaia
# Processing Record 7 of Set 1 | Mataura
# Processing Record 8 of Set 1 | Puerto Ayora
# Processing Record 9 of Set 1 | Tall Kayf
# Processing Record 10 of Set 1 | Dawson Creek
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 | Bredasdorp
# Processing Record 12 of Set 1 | Codrington
# Processing Record 13 of Set 1 | Hobart
# Processing Record 14 of Set 1 | Tokur
# Processing Record 15 of Set 1 | Iqaluit
# Processing Record 16 of Set 1 | Lerwick
# Processing Record 17 of Set 1 | Feicheng
# Processing Record 18 of Set 1 | Balabac
# Processing Record 19 of Set 1 | Vila Velha
# Processing Record 20 of Set 1 | Rikitea
# Processing Record 21 of Set 1 | Sinegor'ye
# City not found. Skipping...
# Processing Record 22 of Set 1 | Shīeli
# Processing Record 23 of Set 1 | Tiznit Province
# Processing Record 24 of Set 1 | Castro
# Processing Record 25 of Set 1 | Barrow
# Processing Record 26 of Set 1 | Port Elizabeth
# Processing Record 27 of Set 1 | Fortuna
# Processing Record 28 of Set 1 | Paidha
# Processing Record 29 of Set 1 | Bhinga
# Processing Record 30 of Set 1 | Saskylakh
# Processing Record 31 of Set 1 | Sweetwater
# Processing Record 32 of Set 1 | Grand Gaube
# Processing Record 17 of Set 4 | Aljezur
# Processing Record 18 of Set 4 | Faya
# Processing Record 19 of Set 4 | Jiaozuo
# Processing Record 20 of Set 4 | Hambantota
# Processing Record 21 of Set 4 | Langsa
# Processing Record 22 of Set 4 | Malbork
# Processing Record 23 of Set 4 | Saint Paul Harbor
# Processing Record 24 of Set 4 | Tingi
# City not found. Skipping...
# Processing Record 25 of Set 4 | Blairmore
# Processing Record 26 of Set 4 | Tarquinia
# Processing Record 27 of Set 4 | Sikasso
# Processing Record 28 of Set 4 | Grindavik
# Processing Record 29 of Set 4 | Bama
# Processing Record 30 of Set 4 | Norman Wells
# Processing Record 31 of Set 4 | Thompson
# Processing Record 32 of Set 4 | Fasa
# Processing Record 33 of Set 4 | Kloulklubed
# Processing Record 34 of Set 4 | Solwezi
# Processing Record 35 of Set 4 | Pisco
# Processing Record 36 of Set 4 | Fort Nelson
# Processing Record 37 of Set 4 | Kupang
# Processing Record 38 of Set 4 | Bonavista
# Processing Record 39 of Set 4 | Geraldton
# Processing Record 40 of Set 4 | Oytal
# Processing Record 41 of Set 4 | Panabá
# Processing Record 42 of Set 4 | Chapada dos Guimarães
# Processing Record 43 of Set 4 | San Patricio
# Processing Record 44 of Set 4 | Dunedin
# Processing Record 45 of Set 4 | Mount Gambier
# Processing Record 46 of Set 4 | Sassandra
# City not found. Skipping...
# Processing Record 47 of Set 4 | Saint-Ambroise
# Processing Record 48 of Set 4 | Paamiut
# Processing Record 49 of Set 4 | La Ronge
# Processing Record 50 of Set 4 | Cidreira
# Processing Record 0 of Set 5 | Sørland
# Processing Record 1 of Set 5 | San Quintín
# Processing Record 2 of Set 5 | Flin Flon
# Processing Record 3 of Set 5 | Mossamedes
# Processing Record 4 of Set 5 | Waipawa
# Processing Record 5 of Set 5 | Ipixuna
# Processing Record 6 of Set 5 | Corn Island
# Processing Record 7 of Set 5 | Ponta Delgada
# Processing Record 8 of Set 5 | Haveli Lakha
# Processing Record 9 of Set 5 | Falam
# Processing Record 10 of Set 5 | Aklavik
# Processing Record 11 of Set 5 | Coolum Beach
# Processing Record 12 of Set 5 | Charters Towers
# Processing Record 13 of Set 5 | Hong Kong
# Processing Record 14 of Set 5 | Severo-Kuril'sk
# Processing Record 15 of Set 5 | Lengshuijiang
# Processing Record 16 of Set 5 | Yuncheng
# Processing Record 17 of Set 5 | Harper
# Processing Record 18 of Set 5 | Padang
# Processing Record 19 of Set 5 | Bambanglipuro
# Processing Record 20 of Set 5 | Mănăştiur
# Processing Record 21 of Set 5 | Vostok
# Processing Record 22 of Set 5 | Shetpe
# Processing Record 23 of Set 5 | Casimcea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 5 | Nanortalik
# Processing Record 25 of Set 5 | Progreso
# Processing Record 26 of Set 5 | Koppies
# Processing Record 27 of Set 5 | Asău
# Processing Record 28 of Set 5 | Nabire
# Processing Record 29 of Set 5 | Kavaratti
# Processing Record 30 of Set 5 | Ixtapa
# Processing Record 31 of Set 5 | Loíza
# Processing Record 32 of Set 5 | Hithadhoo
# Processing Record 33 of Set 5 | Camaná
# Processing Record 34 of Set 5 | Saint-Augustin
# Processing Record 35 of Set 5 | Chifeng
# Processing Record 36 of Set 5 | Ahipara
# Processing Record 37 of Set 5 | Kedrovyy
# Processing Record 38 of Set 5 | Tupik
# City not found. Skipping...
# Processing Record 39 of Set 5 | Inírida
# Processing Record 40 of Set 5 | Quatre Cocos
# Processing Record 41 of Set 5 | Salalah
# Processing Record 42 of Set 5 | Port Lincoln
# City not found. Skipping...
# Processing Record 43 of Set 5 | East London
# Processing Record 44 of Set 5 | Assiniboia
# City not found. Skipping...
# Processing Record 45 of Set 5 | Angola
# Processing Record 46 of Set 5 | Imbituba
# Processing Record 47 of Set 5 | Dondo
# Processing Record 48 of Set 5 | Bilibino
# Processing Record 49 of Set 5 | Nālūt
# Processing Record 50 of Set 5 | Hamilton
# Processing Record 0 of Set 6 | Cabedelo
# Processing Record 1 of Set 6 | Marovoay
# Processing Record 2 of Set 6 | Kalmunai
# City not found. Skipping...
# Processing Record 3 of Set 6 | Poum
# Processing Record 4 of Set 6 | Gamba
# Processing Record 5 of Set 6 | Kangshan
# Processing Record 6 of Set 6 | Alindao
# Processing Record 7 of Set 6 | Te Anau
# Processing Record 8 of Set 6 | Coahuayana Viejo
# Processing Record 9 of Set 6 | Mungaa
# Processing Record 10 of Set 6 | Luwuk
# Processing Record 11 of Set 6 | La Oroya
# Processing Record 12 of Set 6 | Mbandaka
# Processing Record 13 of Set 6 | Sorong
# Processing Record 14 of Set 6 | Hailar
# Processing Record 15 of Set 6 | Kiunga
# Processing Record 16 of Set 6 | Sinnamary
# Processing Record 17 of Set 6 | Pacific Grove
# Processing Record 18 of Set 6 | Gorzów Wielkopolski
# Processing Record 19 of Set 6 | Torbay
# City not found. Skipping...
# Processing Record 20 of Set 6 | Abashiri
# Processing Record 21 of Set 6 | Dwārka
# Processing Record 22 of Set 6 | Talnakh
# Processing Record 23 of Set 6 | Mafinga
# Processing Record 24 of Set 6 | Batemans Bay
# Processing Record 25 of Set 6 | Kirakira
# Processing Record 26 of Set 6 | Fare
# Processing Record 27 of Set 6 | Avera
# Processing Record 28 of Set 6 | Kaitangata
# Processing Record 29 of Set 6 | Isiro
# Processing Record 30 of Set 6 | Krasnosel'kup
# Processing Record 31 of Set 6 | Ibrā’
# Processing Record 32 of Set 6 | Lagoa
# Processing Record 33 of Set 6 | São José da Coroa Grande
# Processing Record 34 of Set 6 | Sept-Îles
# Processing Record 35 of Set 6 | Ozinki
# Processing Record 36 of Set 6 | Burley
# Processing Record 37 of Set 6 | Murgab
# City not found. Skipping...
# Processing Record 38 of Set 6 | Yerbogachën
# Processing Record 39 of Set 6 | Krasnyy Chikoy
# Processing Record 40 of Set 6 | Coos Bay
# City not found. Skipping...
# Processing Record 41 of Set 6 | Upernavik
# Processing Record 42 of Set 6 | Nelson
# Processing Record 43 of Set 6 | Äänekoski
# Processing Record 44 of Set 6 | Khatanga
# Processing Record 45 of Set 6 | Makokou
# Processing Record 46 of Set 6 | Muros
# Processing Record 47 of Set 6 | Juneau
# Processing Record 48 of Set 6 | Beian
# Processing Record 49 of Set 6 | Kieta
# Processing Record 50 of Set 6 | Guanare
# Processing Record 0 of Set 7 | Lüderitz
# Processing Record 1 of Set 7 | Biltine
# Processing Record 2 of Set 7 | Cockburn Town
# Processing Record 3 of Set 7 | Cabo San Lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 37 of Set 9 | Baharly
# Processing Record 38 of Set 9 | Petrila
# Processing Record 39 of Set 9 | Dauriya
# Processing Record 40 of Set 9 | Russell
# Processing Record 41 of Set 9 | Ubari
# Processing Record 42 of Set 9 | Karratha
# Processing Record 43 of Set 9 | Khani
# Processing Record 44 of Set 9 | Puerto Carreño
# Processing Record 45 of Set 9 | Dunda
# Processing Record 46 of Set 9 | Forsytheganj
# Processing Record 47 of Set 9 | Vaitape
# Processing Record 48 of Set 9 | Shaunavon
# Processing Record 49 of Set 9 | Luunja
# Processing Record 50 of Set 9 | Praxédis Guerrero
# Processing Record 0 of Set 10 | Tautira
# Processing Record 1 of Set 10 | Sambava
# Processing Record 2 of Set 10 | Arnedo
# Processing Record 3 of Set 10 | Tunceli
# Processing Record 4 of Set 10 | Piaçabuçu
# Processing Record 5 of Set 10 | Shanhecun
# Processing Record 6 of Set 10 | Saraland
# Processing Record 7 of Set 10 | Comodoro Rivadavia
# Processing Record 8 of Set 10 | Ruteng
# Processing Record 9 of Set 10 | Guerrero Negro
# City not found. Skipping...
# Processing Record 10 of Set 10 | Zapolyarnyy
# Processing Record 11 of Set 10 | Bosaso
# Processing Record 12 of Set 10 | Champerico
# Processing Record 13 of Set 10 | Frontera
# Processing Record 14 of Set 10 | Shache
# Processing Record 15 of Set 10 | Colac
# Processing Record 16 of Set 10 | Mandalgovi
# City not found. Skipping...
# Processing Record 17 of Set 10 | Pimentel
# City not found. Skipping...
# Processing Record 18 of Set 10 | Bullhead City
# Processing Record 19 of Set 10 | Saint-Joseph
# Processing Record 20 of Set 10 | Stolin
# Processing Record 21 of Set 10 | Qidong
# Processing Record 22 of Set 10 | Yanam
# City not found. Skipping...
# Processing Record 23 of Set 10 | Koygorodok
# Processing Record 24 of Set 10 | Manggar
# Processing Record 25 of Set 10 | Lashio
# Processing Record 26 of Set 10 | Ukiah
# Processing Record 27 of Set 10 | Samarai
# Processing Record 28 of Set 10 | Saldanha
# Processing Record 29 of Set 10 | Lagunas
# Processing Record 30 of Set 10 | Namatanai
# Processing Record 31 of Set 10 | Benavente
# Processing Record 32 of Set 10 | Semnan
# Processing Record 33 of Set 10 | Yar-Sale
# Processing Record 34 of Set 10 | Fes
# Processing Record 35 of Set 10 | Panjāb
# Processing Record 36 of Set 10 | Khetia
# Processing Record 37 of Set 10 | Ekhabi
# Processing Record 38 of Set 10 | Pouembout
# Processing Record 39 of Set 10 | Itarema
# Processing Record 40 of Set 10 | Areosa
# Processing Record 41 of Set 10 | Mumford
# Processing Record 42 of Set 10 | Pemberton
# Processing Record 43 of Set 10 | Bozova
# Processing Record 44 of Set 10 | Ust'-Uda
# Processing Record 45 of Set 10 | Morgan City
# City not found. Skipping...
# Processing Record 46 of Set 10 | Niğde
# Processing Record 47 of Set 10 | Nantucket
# Processing Record 48 of Set 10 | Eskil
# Processing Record 49 of Set 10 | Dawei
# Processing Record 50 of Set 10 | Bambous Virieux
# Processing Record 0 of Set 11 | Vao
# Processing Record 1 of Set 11 | Entre Rios
# Processing Record 2 of Set 11 | Laas
# Processing Record 3 of Set 11 | Kiama
# Processing Record 4 of Set 11 | Yulara
# Processing Record 5 of Set 11 | Skagen
# Processing Record 6 of Set 11 | Biswān
# City not found. Skipping...
# Processing Record 7 of Set 11 | Trairi
# Processing Record 8 of Set 11 | Vicuña
# Processing Record 9 of Set 11 | Marsaxlokk
# Processing Record 10 of Set 11 | Sawtell
# Processing Record 11 of Set 11 | Middletown
# Processing Record 12 of Set 11 | Yei
# Processing Record 13 of Set 11 | Rio de Janeiro
# Processing Record 14 of Set 11 | Kutum
# Processing Record 15 of Set 11 | Lucea
# City not found. Skipping...
# Processing Record 16 of Set 11 | Colares
# Processing Record 17 of Set 11 | Shimoda
# Processing Record 18 of Set 11 | Riyadh
# Processing Record 19 of Set 11 | Havøysund
# Processing Record 20 of Set 11 | Alice Springs
# Processing Record 21 of Set 11 | Sur
# Processing Record 22 of Set 11 | Balboa
# Processing Record 23 of Set 11 | Kindu
# Processing Record 24 of Set 11 | Hobyo
# Processing Record 25 of Set 11 | Maricá
# Processing Record 26 of Set 11 | Kaduna
# City not found. Skipping...
# Processing Record 27 of Set 11 | Cape Coast
# Processing Record 28 of Set 11 | Saint Lawrence
# Processing Record 29 of Set 11 | Havre-St-Pierre
# Processing Record 30 of Set 11 | Margate
# Processing Record 31 of Set 11 | Emerald
# Processing Record 32 of Set 11 | Buin
# Processing Record 33 of Set 11 | Shingū
# Processing Record 34 of Set 11 | Hūn
# Processing Record 35 of Set 11 | Miles City
# Processing Record 36 of Set 11 | Tabas
# City not found. Skipping...
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data into dictionary
weather_dict = {
    "City": names,
    "Lat": latitude,
    "Lng": longitude,
    "Max Temp": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}
# convert dict into df
weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
weather_df.to_csv("weather_df", encoding="utf-8", index=False)

# %%
weather_df.head(100)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Chokurdakh  70.63  147.92     74.37        44         100       17.83
# 1         Ishimbay  53.45   56.04     61.41        95          18        3.18
# 2       Port Keats -14.25  129.55     77.22        40           0        6.73
# 3            Pevek  69.70  170.31     48.20        56           0        6.04
# 4      George Town   5.41  100.34     82.40        94          20        5.84
# ..             ...    ...     ...       ...       ...         ...         ...
# 95  Ribeira Grande  38.52  -28.70     69.24        78          48        3.11
# 96       Okakarara -20.58   17.43     42.26        61           0        5.32
# 97         Kirensk  57.79  108.11     62.17        50           6        2.51
# 98        Waingapu  -9.66  120.26     79.48        68          54       11.52
# 99        Hermanus -34.42   19.23     54.00        95          19        4.00
#
#    Country        Date
# 0       RU  1595206521
# 1       RU  1595206521
# 2       AU  1595206521
# 3       RU  1595206521
# 4       MY  1595206521
# ..     ...         ...
# 95      PT  1595206498
# 96      NA  1595206538
# 97      RU  1595206538
# 98      ID  1595206497
# 99      ZA  1595206538
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
heavy_humid = len(weather_df.loc[(weather_df["Humidity"] > 100)])
heavy_humid
# we can skip this step and move onto the plotting
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# making a scatter plot of lat vs max temp
plt.title("City Latitude vs. Max Temperature (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], alpha=.75, edgecolor="black");

plt.savefig("Lat_Vs_MaxTemp.png")
# Out:
# This plot shows the relationship between the proximity of the equator and the temp. The closer you are to the equator, the hotter it gets.

# %%
print(f"This plot shows the relationship between the proximity of the equator and the temp. The closer you are to the equator, the hotter it gets.")
# Out:
# This plot shows the relationship between the proximity of the equator and the temp. The closer you are to the equator, the hotter it gets.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# making a scatter plot of lat vs humidity
plt.title("City Latitude vs. Humidity (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.scatter(weather_df["Lat"], weather_df["Humidity"], alpha=.75, edgecolor="black");

plt.savefig("Lat_Vs_Humidity.png")

# %%
print(f"This plot shows the relationship between the proximity of the equator and the humidity. The closer you are to the equator, the more humid it gets.")
# Out:
# This plot shows the relationship between the proximity of the equator and the humidity. The closer you are to the equator, the more humid it gets.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# making a scatter plot of lat vs cloudiness
plt.title("City Latitude vs. Cloudiness (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], alpha=.75, edgecolor="black");

plt.savefig("Lat_Vs_Cloudiness.png")

# %%
print(f"This plot shows the relationship between the proximity of the equator and the percentage of cloudiness. The southern hemisphere is not as cloudy as the northern hemispher.")
# Out:
# This plot shows the relationship between the proximity of the equator and the percentage of cloudiness. The southern hemisphere is not as cloudy as the northern hemispher.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# making a scatter plot of lat vs cloudiness
plt.title("City Latitude vs. Wind Speed (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], alpha=.75, edgecolor="black");

plt.savefig("Lat_Vs_Wind.png")

# %%
print(f"This plot shows the relationship between the proximity of the equator and the wind speed. The closer you are to the equator, the less chance of getting higher wind speeds you have.")
# Out:
# This plot shows the relationship between the proximity of the equator and the wind speed. The closer you are to the equator, the less chance of getting higher wind speeds you have.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north = weather_df.loc[weather_df["Lat"]>.01]
south = weather_df.loc[weather_df["Lat"]<-.01]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# making a scatter plot of northern hemi - max temp vs latitude
north_x_val = north["Lat"]
north_y_val = north["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x_val, north_y_val)
regress_values = north_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.ylim(0,105)
plt.xlim(0, 80)
plt.scatter(north_x_val, north_y_val);
plt.plot(north_x_val, regress_values, "r-")
plt.annotate(line_eq,(10,37.5),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("North_Hem_Max_Temp_Vs_Lat.png")
# Out:
# The r-squared is: -0.6193193958587668

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# making a scatter plot of southern hemi - max temp vs latitude
south_x_val = south["Lat"]
south_y_val = south["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x_val, south_y_val)
regress_values = south_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.ylim(30,95)
plt.xlim(-60, .1)
plt.scatter(south_x_val, south_y_val);
plt.plot(south_x_val, regress_values, "r-")
plt.annotate(line_eq,(-50,87.5),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("South_Hem_Max_Temp_Vs_Lat.png")
# Out:
# The r-squared is: 0.7056898296355572

# %%
print(f"The two regression models are not similar, as one is a positive relationship (the southern hemispher) and one is not (northen hemisphere). ")
# Out:
# The two regression models are not similar, as one is a positive relationship (the southern hemispher) and one is not (northen hemisphere).

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# making a scatter plot of northnern hemi - humidity vs latitude
north_x_val = north["Lat"]
north_y_val = north["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x_val, north_y_val)
regress_values = north_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# plt.ylim(0,105)
# plt.xlim(80, 0)
plt.scatter(north_x_val, north_y_val);
plt.plot(north_x_val, regress_values, "r-")
plt.annotate(line_eq,(46.5,20),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("North_Hem_Humid_Vs_Lat.png")
# Out:
# The r-squared is: -0.13541904208303426

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# making a scatter plot of southern hemi - humidity vs latitude
south_x_val = south["Lat"]
south_y_val = south["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x_val, south_y_val)
regress_values = south_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# plt.ylim(0,105)
# plt.xlim(80, 0)
plt.scatter(south_x_val, south_y_val);
plt.plot(south_x_val, regress_values, "r-")
plt.annotate(line_eq,(-56.5,20),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("South_Hem_Humid_Vs_Lat.png")
# Out:
# The r-squared is: 0.01778423594828527

# %%
print(f"These two regression models are also not similar, and is very difficult to predict because of the flatness of the regression line. ")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# making a scatter plot of northnern hemi - humidity vs latitude
north_x_val = north["Lat"]
north_y_val = north["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x_val, north_y_val)
regress_values = north_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# plt.ylim(0,105)
# plt.xlim(80, 0)
plt.scatter(north_x_val, north_y_val);
plt.plot(north_x_val, regress_values, "r-")
plt.annotate(line_eq,(46.5,25),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("North_Hem_Cloudiness_Vs_Lat.png")
# Out:
# The r-squared is: -0.10963683905816052

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# making a scatter plot of southern hemi - humidity vs latitude
south_x_val = south["Lat"]
south_y_val = south["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x_val, south_y_val)
regress_values = south_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# plt.ylim(0,105)
# plt.xlim(100, 0)
plt.scatter(south_x_val, south_y_val);
plt.plot(south_x_val, regress_values, "r-")
plt.annotate(line_eq,(-55.5,23),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("South_Hem_Cloudiness_Vs_Lat.png")
# Out:
# The r-squared is: -0.18144822786376444

# %%
print(f"These two regression lines are a bit similar as they are both negative.")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# making a scatter plot of northnern hemi - humidity vs latitude
north_x_val = north["Lat"]
north_y_val = north["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_x_val, north_y_val)
regress_values = north_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# plt.ylim(0,105)
# plt.xlim(80, 0)
plt.scatter(north_x_val, north_y_val);
plt.plot(north_x_val, regress_values, "r-")
plt.annotate(line_eq,(46.5,25),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("North_Hem_Wind_Speed_Vs_Lat.png")
# Out:
# The r-squared is: -0.08315210977118921

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# making a scatter plot of southern hemi - humidity vs latitude
south_x_val = south["Lat"]
south_y_val = south["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_x_val, south_y_val)
regress_values = south_x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (07/19/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# plt.ylim(0,105)
# plt.xlim(100, 0)
plt.scatter(south_x_val, south_y_val);
plt.plot(south_x_val, regress_values, "r-")
plt.annotate(line_eq,(-55.5,21),fontsize=15,color="red");
print(f"The r-squared is: {rvalue}")
plt.savefig("South_Hem_Wind_Speed_Vs_Lat.png")
# Out:
# The r-squared is: -0.026507917760122998

# %%
print(f"These two regression models are also not similar, and is very difficult to predict because of the flatness of the regression line. ")
# Out:
# These two regression models are also not similar, and is very difficult to predict because of the flatness of the regression line.
